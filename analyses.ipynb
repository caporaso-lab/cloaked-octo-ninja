# %%
import pandas as pd
import numpy as np
from glob import glob

data_set_ids = ['88-soils', 'whole-body', 'moving-pictures']
order = ['uc','ucr','ucrC','ucrss','ucrss_wfilter',
         'uc_fast','ucr_fast','ucrC_fast','ucrss_fast','ucrss_fast_wfilter']

method_descriptions = pd.io.parsers.read_csv('raw-tables/method-descriptions.tsv', sep='\t', index_col=0)

write_xls_files = False

# %% [markdown]
# ## Table 1: Method descriptions

# %%
if write_xls_files: method_descriptions.to_excel('tables/table1.xlsx', na_rep='NA', float_format="%1.3f")
method_descriptions
# Out:
#                                                                 title  \
# abbreviation
# uc                                                            De novo
# ucr                                             Legacy open reference
# ucrC                                                 Closed reference
# ucrss                                       Subsampled open reference
# ucrss_wfilter                     Subsampled open reference, filtered
# uc_fast                                        De novo, fast settings
# ucr_fast                         Legacy open reference, fast settings
# ucrC_fast                             Closed reference, fast settings
# ucrss_fast                   Subsampled open reference, fast settings
# ucrss_fast_wfilter  Subsampled open reference, filtered, fast sett...
# ucr_fast_O29_r82    Legacy open reference, fast settings, 82% refe...
# ucr_fast_O29_r97    Legacy open reference, fast settings, 29 proce...
# ucrss_fast_O29_r82  Subsampled open reference, fast settings, 82% ...
# ucrss_fast_O29_r97  Subsampled open reference, fast settings, 29 p...
# ucrss_fast_O29_s1   Subsampled open reference, fast settings, 29 p...
#
#                                           command  max_accepts  max_rejects  \
# abbreviation
# uc                           pick_de_novo_otus.py           20          500
# ucr                          pick_de_novo_otus.py           20          500
# ucrC                pick_closed_reference_otus.py           20          500
# ucrss                 pick_open_reference_otus.py           20          500
# ucrss_wfilter         pick_open_reference_otus.py           20          500
# uc_fast                      pick_de_novo_otus.py            1            8
# ucr_fast                     pick_de_novo_otus.py            1            8
# ucrC_fast           pick_closed_reference_otus.py            1            8
# ucrss_fast            pick_open_reference_otus.py            1            8
# ucrss_fast_wfilter    pick_open_reference_otus.py            1            8
# ucr_fast_O29_r82             pick_de_novo_otus.py            1            8
# ucr_fast_O29_r97             pick_de_novo_otus.py            1            8
# ucrss_fast_O29_r82    pick_open_reference_otus.py            1            8
# ucrss_fast_O29_r97    pick_open_reference_otus.py            1            8
# ucrss_fast_O29_s1     pick_open_reference_otus.py            1            8
#
#                     stepwords  wordlength  prefilter_percent_id  min_otu_size  \
# abbreviation
# uc                         20          12                   NaN           NaN
# ucr                        20          12                   NaN           NaN
# ucrC                       20          12                   NaN           NaN
# ucrss                      20          12                   0.0             1
# ucrss_wfilter              20          12                   0.6             1
# uc_fast                     8           8                   NaN           NaN
# ucr_fast                    8           8                   NaN           NaN
# ucrC_fast                   8           8                   NaN           NaN
# ucrss_fast                  8           8                   0.0             1
# ucrss_fast_wfilter          8           8                   0.6             1
# ucr_fast_O29_r82            8           8                   0.0             1
# ucr_fast_O29_r97            8           8                   0.0             1
# ucrss_fast_O29_r82          8           8                   0.0             1
# ucrss_fast_O29_r97          8           8                   0.0             1
# ucrss_fast_O29_s1           8           8                   0.0             1
#
#                    speed_mode  processors  reference_percent_id  \
# abbreviation
# uc                       slow           1                  0.97
# ucr                      slow          10                  0.97
# ucrC                     slow          10                  0.97
# ucrss                    slow          10                  0.97
# ucrss_wfilter            slow          10                  0.97
# uc_fast                  fast           1                  0.97
# ucr_fast                 fast          10                  0.97
# ucrC_fast                fast          10                  0.97
# ucrss_fast               fast          10                  0.97
# ucrss_fast_wfilter       fast          10                  0.97
# ucr_fast_O29_r82         fast          29                  0.82
# ucr_fast_O29_r97         fast          29                  0.97
# ucrss_fast_O29_r82       fast          29                  0.82
# ucrss_fast_O29_r97       fast          29                  0.97
# ucrss_fast_O29_s1        fast          29                  0.97
#
#                     subsample_fraction
# abbreviation
# uc                                 NaN
# ucr                                NaN
# ucrC                               NaN
# ucrss                            0.001
# ucrss_wfilter                    0.001
# uc_fast                            NaN
# ucr_fast                           NaN
# ucrC_fast                          NaN
# ucrss_fast                       0.001
# ucrss_fast_wfilter               0.001
# ucr_fast_O29_r82                 0.001
# ucr_fast_O29_r97                 0.001
# ucrss_fast_O29_r82               0.001
# ucrss_fast_O29_r97               0.001
# ucrss_fast_O29_s1                0.100
#
# [15 rows x 12 columns]

# %% [markdown]
# ## Table 2: Alpha diversity correlations by method

# %%
adiv_fp_sets = [glob('%s-otus/*/adiv*txt' % id_) for id_ in data_set_ids]
adiv_results = {}
for data_set_id, adiv_fp_set in zip(data_set_ids, adiv_fp_sets):
    df = None
    for fp in adiv_fp_set:
        run_id = fp.split('/')[1]
        new_df = pd.DataFrame.from_csv(fp, sep='\t')
        new_df.columns = ['%s.%s' % (c.lower(), run_id) for c in new_df.columns]
        if df is None:
            df = new_df
        else:
            df = pd.merge(df, new_df,right_index=True,left_index=True)
    for metric in ['pd', 'observed_species']:
        id_ = (data_set_id,metric)
        # this loc-based indexing seems clunky - there must be a better way to 
        # do this in pandas (basically, select all columns where the name contains
        # a string)
        corr_table = df.loc[:,[c for c in df.columns if metric in c]].corr()
        # rename and re-order the rows and columns
        corr_table.index = [c.split('.')[1] for c in corr_table.index]
        corr_table.columns = [c.split('.')[1] for c in corr_table.columns]
        corr_table = corr_table.reindex_axis(order,axis=0).reindex_axis(order,axis=1)
        adiv_results[id_] = corr_table

# %%
if write_xls_files: adiv_results[('88-soils', 'pd')].to_excel('tables/table2a.xlsx', na_rep='NA', float_format="%1.3f")
adiv_results[('88-soils', 'pd')]
# Out:
#                           uc       ucr      ucrC     ucrss  ucrss_wfilter  \
# uc                  1.000000  0.950810  0.932749  0.933510       0.952565
# ucr                 0.950810  1.000000  0.902187  0.930701       0.930193
# ucrC                0.932749  0.902187  1.000000  0.893631       0.908745
# ucrss               0.933510  0.930701  0.893631  1.000000       0.929412
# ucrss_wfilter       0.952565  0.930193  0.908745  0.929412       1.000000
# uc_fast             0.955606  0.945996  0.905111  0.944127       0.951712
# ucr_fast            0.936157  0.940277  0.914053  0.935030       0.933274
# ucrC_fast           0.926662  0.903199  0.977595  0.893611       0.902546
# ucrss_fast          0.947673  0.952477  0.902405  0.947867       0.930598
# ucrss_fast_wfilter  0.946606  0.943609  0.910766  0.948666       0.943046
#
#                      uc_fast  ucr_fast  ucrC_fast  ucrss_fast  \
# uc                  0.955606  0.936157   0.926662    0.947673
# ucr                 0.945996  0.940277   0.903199    0.952477
# ucrC                0.905111  0.914053   0.977595    0.902405
# ucrss               0.944127  0.935030   0.893611    0.947867
# ucrss_wfilter       0.951712  0.933274   0.902546    0.930598
# uc_fast             1.000000  0.952704   0.898282    0.956454
# ucr_fast            0.952704  1.000000   0.914263    0.950392
# ucrC_fast           0.898282  0.914263   1.000000    0.902216
# ucrss_fast          0.956454  0.950392   0.902216    1.000000
# ucrss_fast_wfilter  0.960493  0.952351   0.902507    0.962338
#
#                     ucrss_fast_wfilter
# uc                            0.946606
# ucr                           0.943609
# ucrC                          0.910766
# ucrss                         0.948666
# ucrss_wfilter                 0.943046
# uc_fast                       0.960493
# ucr_fast                      0.952351
# ucrC_fast                     0.902507
# ucrss_fast                    0.962338
# ucrss_fast_wfilter            1.000000
#
# [10 rows x 10 columns]

# %%
if write_xls_files: adiv_results[('moving-pictures', 'pd')].to_excel('tables/table2b.xlsx', na_rep='NA', float_format="%1.3f")
adiv_results[('moving-pictures', 'pd')]
# Out:
#                           uc       ucr      ucrC     ucrss  ucrss_wfilter  \
# uc                  1.000000  0.995736  0.992960  0.995918       0.995596
# ucr                 0.995736  1.000000  0.992644  0.996527       0.997235
# ucrC                0.992960  0.992644  1.000000  0.994053       0.991472
# ucrss               0.995918  0.996527  0.994053  1.000000       0.996130
# ucrss_wfilter       0.995596  0.997235  0.991472  0.996130       1.000000
# uc_fast             0.994955  0.995112  0.994132  0.996035       0.994251
# ucr_fast            0.995661  0.995891  0.993919  0.996789       0.995429
# ucrC_fast           0.992341  0.992371  0.997675  0.993736       0.991241
# ucrss_fast          0.995695  0.995859  0.994638  0.996859       0.995604
# ucrss_fast_wfilter  0.995864  0.996714  0.994202  0.997034       0.996436
#
#                      uc_fast  ucr_fast  ucrC_fast  ucrss_fast  \
# uc                  0.994955  0.995661   0.992341    0.995695
# ucr                 0.995112  0.995891   0.992371    0.995859
# ucrC                0.994132  0.993919   0.997675    0.994638
# ucrss               0.996035  0.996789   0.993736    0.996859
# ucrss_wfilter       0.994251  0.995429   0.991241    0.995604
# uc_fast             1.000000  0.996530   0.994057    0.996510
# ucr_fast            0.996530  1.000000   0.993591    0.996812
# ucrC_fast           0.994057  0.993591   1.000000    0.994279
# ucrss_fast          0.996510  0.996812   0.994279    1.000000
# ucrss_fast_wfilter  0.996299  0.996927   0.993998    0.996822
#
#                     ucrss_fast_wfilter
# uc                            0.995864
# ucr                           0.996714
# ucrC                          0.994202
# ucrss                         0.997034
# ucrss_wfilter                 0.996436
# uc_fast                       0.996299
# ucr_fast                      0.996927
# ucrC_fast                     0.993998
# ucrss_fast                    0.996822
# ucrss_fast_wfilter            1.000000
#
# [10 rows x 10 columns]

# %%
if write_xls_files: adiv_results[('whole-body', 'pd')].to_excel('tables/table2c.xlsx', na_rep='NA', float_format="%1.3f")
adiv_results[('whole-body', 'pd')]
# Out:
#                           uc       ucr      ucrC     ucrss  ucrss_wfilter  \
# uc                  1.000000  0.985137  0.957040  0.984981       0.984775
# ucr                 0.985137  1.000000  0.955564  0.989950       0.988868
# ucrC                0.957040  0.955564  1.000000  0.961397       0.958381
# ucrss               0.984981  0.989950  0.961397  1.000000       0.990865
# ucrss_wfilter       0.984775  0.988868  0.958381  0.990865       1.000000
# uc_fast             0.984090  0.987748  0.958510  0.987546       0.985185
# ucr_fast            0.985665  0.987070  0.960640  0.989638       0.988750
# ucrC_fast           0.961456  0.959910  0.990411  0.964492       0.963320
# ucrss_fast          0.982975  0.987496  0.952869  0.989253       0.987431
# ucrss_fast_wfilter  0.984321  0.985933  0.961033  0.987182       0.984912
#
#                      uc_fast  ucr_fast  ucrC_fast  ucrss_fast  \
# uc                  0.984090  0.985665   0.961456    0.982975
# ucr                 0.987748  0.987070   0.959910    0.987496
# ucrC                0.958510  0.960640   0.990411    0.952869
# ucrss               0.987546  0.989638   0.964492    0.989253
# ucrss_wfilter       0.985185  0.988750   0.963320    0.987431
# uc_fast             1.000000  0.986204   0.960893    0.986490
# ucr_fast            0.986204  1.000000   0.964924    0.987977
# ucrC_fast           0.960893  0.964924   1.000000    0.957054
# ucrss_fast          0.986490  0.987977   0.957054    1.000000
# ucrss_fast_wfilter  0.985077  0.988788   0.965236    0.986223
#
#                     ucrss_fast_wfilter
# uc                            0.984321
# ucr                           0.985933
# ucrC                          0.961033
# ucrss                         0.987182
# ucrss_wfilter                 0.984912
# uc_fast                       0.985077
# ucr_fast                      0.988788
# ucrC_fast                     0.965236
# ucrss_fast                    0.986223
# ucrss_fast_wfilter            1.000000
#
# [10 rows x 10 columns]

# %%
if write_xls_files: adiv_results[('88-soils', 'observed_species')].to_excel('tables/table2d.xlsx', na_rep='NA', float_format="%1.3f")
adiv_results[('88-soils', 'observed_species')]
# Out:
#                           uc       ucr      ucrC     ucrss  ucrss_wfilter  \
# uc                  1.000000  0.947875  0.879873  0.909483       0.924238
# ucr                 0.947875  1.000000  0.904662  0.946052       0.947025
# ucrC                0.879873  0.904662  1.000000  0.925964       0.888274
# ucrss               0.909483  0.946052  0.925964  1.000000       0.931844
# ucrss_wfilter       0.924238  0.947025  0.888274  0.931844       1.000000
# uc_fast             0.935259  0.947314  0.882334  0.923371       0.943087
# ucr_fast            0.933534  0.952570  0.907653  0.934916       0.946177
# ucrC_fast           0.876867  0.902627  0.972994  0.915025       0.884305
# ucrss_fast          0.924938  0.938155  0.910432  0.930894       0.932178
# ucrss_fast_wfilter  0.912961  0.932401  0.895664  0.928529       0.926691
#
#                      uc_fast  ucr_fast  ucrC_fast  ucrss_fast  \
# uc                  0.935259  0.933534   0.876867    0.924938
# ucr                 0.947314  0.952570   0.902627    0.938155
# ucrC                0.882334  0.907653   0.972994    0.910432
# ucrss               0.923371  0.934916   0.915025    0.930894
# ucrss_wfilter       0.943087  0.946177   0.884305    0.932178
# uc_fast             1.000000  0.942244   0.882958    0.940951
# ucr_fast            0.942244  1.000000   0.908362    0.942923
# ucrC_fast           0.882958  0.908362   1.000000    0.904095
# ucrss_fast          0.940951  0.942923   0.904095    1.000000
# ucrss_fast_wfilter  0.939832  0.931863   0.905611    0.952921
#
#                     ucrss_fast_wfilter
# uc                            0.912961
# ucr                           0.932401
# ucrC                          0.895664
# ucrss                         0.928529
# ucrss_wfilter                 0.926691
# uc_fast                       0.939832
# ucr_fast                      0.931863
# ucrC_fast                     0.905611
# ucrss_fast                    0.952921
# ucrss_fast_wfilter            1.000000
#
# [10 rows x 10 columns]

# %%
if write_xls_files: adiv_results[('moving-pictures', 'observed_species')].to_excel('tables/table2e.xlsx', na_rep='NA', float_format="%1.3f")
adiv_results[('moving-pictures', 'observed_species')]
# Out:
#                           uc       ucr      ucrC     ucrss  ucrss_wfilter  \
# uc                  1.000000  0.992461  0.983973  0.992078       0.992313
# ucr                 0.992461  1.000000  0.994303  0.998253       0.998186
# ucrC                0.983973  0.994303  1.000000  0.994695       0.994748
# ucrss               0.992078  0.998253  0.994695  1.000000       0.998285
# ucrss_wfilter       0.992313  0.998186  0.994748  0.998285       1.000000
# uc_fast             0.988647  0.991920  0.983908  0.991935       0.991651
# ucr_fast            0.990092  0.996989  0.993300  0.997188       0.997157
# ucrC_fast           0.978429  0.990556  0.996874  0.991311       0.991281
# ucrss_fast          0.989429  0.996875  0.993777  0.997034       0.996954
# ucrss_fast_wfilter  0.989610  0.997030  0.993611  0.997209       0.997097
#
#                      uc_fast  ucr_fast  ucrC_fast  ucrss_fast  \
# uc                  0.988647  0.990092   0.978429    0.989429
# ucr                 0.991920  0.996989   0.990556    0.996875
# ucrC                0.983908  0.993300   0.996874    0.993777
# ucrss               0.991935  0.997188   0.991311    0.997034
# ucrss_wfilter       0.991651  0.997157   0.991281    0.996954
# uc_fast             1.000000  0.992937   0.980686    0.991777
# ucr_fast            0.992937  1.000000   0.992169    0.997906
# ucrC_fast           0.980686  0.992169   1.000000    0.992683
# ucrss_fast          0.991777  0.997906   0.992683    1.000000
# ucrss_fast_wfilter  0.991937  0.998061   0.992397    0.997988
#
#                     ucrss_fast_wfilter
# uc                            0.989610
# ucr                           0.997030
# ucrC                          0.993611
# ucrss                         0.997209
# ucrss_wfilter                 0.997097
# uc_fast                       0.991937
# ucr_fast                      0.998061
# ucrC_fast                     0.992397
# ucrss_fast                    0.997988
# ucrss_fast_wfilter            1.000000
#
# [10 rows x 10 columns]

# %%
if write_xls_files: adiv_results[('whole-body', 'observed_species')].to_excel('tables/table2f.xlsx', na_rep='NA', float_format="%1.3f")
adiv_results[('whole-body', 'observed_species')]
# Out:
#                           uc       ucr      ucrC     ucrss  ucrss_wfilter  \
# uc                  1.000000  0.986013  0.970654  0.986054       0.986288
# ucr                 0.986013  1.000000  0.983916  0.995433       0.995315
# ucrC                0.970654  0.983916  1.000000  0.984706       0.983561
# ucrss               0.986054  0.995433  0.984706  1.000000       0.995365
# ucrss_wfilter       0.986288  0.995315  0.983561  0.995365       1.000000
# uc_fast             0.992712  0.986973  0.970210  0.986947       0.986130
# ucr_fast            0.987933  0.992700  0.980584  0.992549       0.992597
# ucrC_fast           0.971591  0.979658  0.992099  0.980568       0.979232
# ucrss_fast          0.988239  0.992898  0.980124  0.992644       0.991829
# ucrss_fast_wfilter  0.987425  0.992813  0.979129  0.992455       0.992433
#
#                      uc_fast  ucr_fast  ucrC_fast  ucrss_fast  \
# uc                  0.992712  0.987933   0.971591    0.988239
# ucr                 0.986973  0.992700   0.979658    0.992898
# ucrC                0.970210  0.980584   0.992099    0.980124
# ucrss               0.986947  0.992549   0.980568    0.992644
# ucrss_wfilter       0.986130  0.992597   0.979232    0.991829
# uc_fast             1.000000  0.988851   0.971697    0.989586
# ucr_fast            0.988851  1.000000   0.981125    0.994334
# ucrC_fast           0.971697  0.981125   1.000000    0.981586
# ucrss_fast          0.989586  0.994334   0.981586    1.000000
# ucrss_fast_wfilter  0.988207  0.994478   0.979289    0.994629
#
#                     ucrss_fast_wfilter
# uc                            0.987425
# ucr                           0.992813
# ucrC                          0.979129
# ucrss                         0.992455
# ucrss_wfilter                 0.992433
# uc_fast                       0.988207
# ucr_fast                      0.994478
# ucrC_fast                     0.979289
# ucrss_fast                    0.994629
# ucrss_fast_wfilter            1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# ## Table 3: Beta diversity correlation by method

# %%
bdiv_results = {}
for metric in ['unweighted_unifrac', 'weighted_unifrac']:
    for data_set_id in data_set_ids:
        id_ = (data_set_id,metric)
        fp = '%s-otus/%s_mantel_results/mantel_results.txt' % id_
        df = pd.DataFrame.from_csv(fp, sep='\t', header=4, index_col=False)
        df = df.pivot(index='DM1', columns='DM2', values='Mantel r statistic')
        # re-name and re-order rows and columns
        df.index = [e.split('/')[1] for e in df.index]
        df.columns = [e.split('/')[1] for e in df.columns]
        df = df.reindex_axis(order,axis=0).reindex_axis(order,axis=1)
        bdiv_results[id_] = df

# %%
if write_xls_files: bdiv_results[('88-soils', 'unweighted_unifrac')].to_excel('tables/table3a.xlsx', na_rep='NA', float_format="%1.3f")
bdiv_results[('88-soils', 'unweighted_unifrac')]
# Out:
#                     uc      ucr     ucrC    ucrss  ucrss_wfilter  uc_fast  \
# uc                 NaN  0.93487  0.90823  0.94364        0.94208  0.93926
# ucr                NaN      NaN  0.91458  0.93982        0.94465  0.93425
# ucrC               NaN      NaN      NaN  0.91656        0.90959  0.92586
# ucrss              NaN      NaN      NaN      NaN        0.93954  0.93791
# ucrss_wfilter      NaN      NaN      NaN      NaN            NaN  0.93439
# uc_fast            NaN      NaN      NaN      NaN            NaN      NaN
# ucr_fast           NaN      NaN      NaN      NaN            NaN      NaN
# ucrC_fast          NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast         NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast_wfilter NaN      NaN      NaN      NaN            NaN      NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                   0.94472    0.90865     0.94259             0.94149
# ucr                  0.94212    0.91776     0.94393             0.94881
# ucrC                 0.91308    0.94977     0.91709             0.91966
# ucrss                0.94464    0.91370     0.93830             0.94230
# ucrss_wfilter        0.94291    0.90714     0.94156             0.94136
# uc_fast              0.93829    0.91969     0.93888             0.94116
# ucr_fast                 NaN    0.90853     0.94642             0.94651
# ucrC_fast                NaN        NaN     0.91736             0.92433
# ucrss_fast               NaN        NaN         NaN             0.94494
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: bdiv_results[('moving-pictures', 'unweighted_unifrac')].to_excel('tables/table3b.xlsx', na_rep='NA', float_format="%1.3f")
bdiv_results[('moving-pictures', 'unweighted_unifrac')]
# Out:
#                     uc      ucr     ucrC    ucrss  ucrss_wfilter  uc_fast  \
# uc                 NaN  0.99196  0.97423  0.98823        0.98824  0.99195
# ucr                NaN      NaN  0.98180  0.99162        0.99146  0.99107
# ucrC               NaN      NaN      NaN  0.98624        0.98470  0.97287
# ucrss              NaN      NaN      NaN      NaN        0.98983  0.98847
# ucrss_wfilter      NaN      NaN      NaN      NaN            NaN  0.98587
# uc_fast            NaN      NaN      NaN      NaN            NaN      NaN
# ucr_fast           NaN      NaN      NaN      NaN            NaN      NaN
# ucrC_fast          NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast         NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast_wfilter NaN      NaN      NaN      NaN            NaN      NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                   0.99050    0.97744     0.99128             0.99194
# ucr                  0.99236    0.98375     0.99256             0.99300
# ucrC                 0.98162    0.99387     0.98050             0.98086
# ucrss                0.99174    0.98729     0.99157             0.99134
# ucrss_wfilter        0.98971    0.98566     0.98950             0.99055
# uc_fast              0.99087    0.97569     0.99175             0.99148
# ucr_fast                 NaN    0.98330     0.99293             0.99220
# ucrC_fast                NaN        NaN     0.98231             0.98313
# ucrss_fast               NaN        NaN         NaN             0.99275
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: bdiv_results[('whole-body', 'unweighted_unifrac')].to_excel('tables/table3c.xlsx', na_rep='NA', float_format="%1.3f")
bdiv_results[('whole-body', 'unweighted_unifrac')]
# Out:
#                     uc      ucr     ucrC    ucrss  ucrss_wfilter  uc_fast  \
# uc                 NaN  0.93502  0.89081  0.93757        0.93633  0.92982
# ucr                NaN      NaN  0.89946  0.94835        0.95012  0.93418
# ucrC               NaN      NaN      NaN  0.90765        0.89852  0.87809
# ucrss              NaN      NaN      NaN      NaN        0.95252  0.93798
# ucrss_wfilter      NaN      NaN      NaN      NaN            NaN  0.93661
# uc_fast            NaN      NaN      NaN      NaN            NaN      NaN
# ucr_fast           NaN      NaN      NaN      NaN            NaN      NaN
# ucrC_fast          NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast         NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast_wfilter NaN      NaN      NaN      NaN            NaN      NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                   0.92633    0.88941     0.93279             0.92547
# ucr                  0.93139    0.89533     0.94144             0.92738
# ucrC                 0.88532    0.95207     0.89723             0.87790
# ucrss                0.93623    0.90499     0.94548             0.92768
# ucrss_wfilter        0.93996    0.89442     0.94125             0.93176
# uc_fast              0.94199    0.87167     0.93906             0.93754
# ucr_fast                 NaN    0.88760     0.93944             0.94811
# ucrC_fast                NaN        NaN     0.89139             0.87890
# ucrss_fast               NaN        NaN         NaN             0.93340
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: bdiv_results[('88-soils', 'weighted_unifrac')].to_excel('tables/table3d.xlsx', na_rep='NA', float_format="%1.3f")
bdiv_results[('88-soils', 'weighted_unifrac')]
# Out:
#                     uc      ucr     ucrC    ucrss  ucrss_wfilter  uc_fast  \
# uc                 NaN  0.89611  0.93569  0.95121        0.90142  0.92525
# ucr                NaN      NaN  0.89623  0.88943        0.96587  0.89103
# ucrC               NaN      NaN      NaN  0.91903        0.91355  0.90626
# ucrss              NaN      NaN      NaN      NaN        0.89965  0.91691
# ucrss_wfilter      NaN      NaN      NaN      NaN            NaN  0.88544
# uc_fast            NaN      NaN      NaN      NaN            NaN      NaN
# ucr_fast           NaN      NaN      NaN      NaN            NaN      NaN
# ucrC_fast          NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast         NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast_wfilter NaN      NaN      NaN      NaN            NaN      NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                   0.93708    0.92377     0.95616             0.90235
# ucr                  0.93933    0.89456     0.90146             0.94684
# ucrC                 0.92836    0.98438     0.93128             0.89627
# ucrss                0.94744    0.90325     0.94914             0.89874
# ucrss_wfilter        0.93761    0.91087     0.89856             0.93959
# uc_fast              0.90934    0.89783     0.91872             0.87395
# ucr_fast                 NaN    0.92017     0.95189             0.95986
# ucrC_fast                NaN        NaN     0.91809             0.89003
# ucrss_fast               NaN        NaN         NaN             0.91784
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: bdiv_results[('moving-pictures', 'weighted_unifrac')].to_excel('tables/table3e.xlsx', na_rep='NA', float_format="%1.3f")
bdiv_results[('moving-pictures', 'weighted_unifrac')]
# Out:
#                     uc      ucr     ucrC    ucrss  ucrss_wfilter  uc_fast  \
# uc                 NaN  0.97127  0.94939  0.96991        0.97333  0.97169
# ucr                NaN      NaN  0.92765  0.95164        0.95177  0.95722
# ucrC               NaN      NaN      NaN  0.96042        0.94021  0.94837
# ucrss              NaN      NaN      NaN      NaN        0.93761  0.96519
# ucrss_wfilter      NaN      NaN      NaN      NaN            NaN  0.94615
# uc_fast            NaN      NaN      NaN      NaN            NaN      NaN
# ucr_fast           NaN      NaN      NaN      NaN            NaN      NaN
# ucrC_fast          NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast         NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast_wfilter NaN      NaN      NaN      NaN            NaN      NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                   0.97675    0.94938     0.97358             0.96645
# ucr                  0.95820    0.92801     0.95995             0.95402
# ucrC                 0.93388    0.99940     0.96532             0.93212
# ucrss                0.95474    0.95964     0.98007             0.93228
# ucrss_wfilter        0.96638    0.94095     0.95057             0.96651
# uc_fast              0.96951    0.94818     0.97086             0.94925
# ucr_fast                 NaN    0.93403     0.96671             0.96732
# ucrC_fast                NaN        NaN     0.96474             0.93239
# ucrss_fast               NaN        NaN         NaN             0.95120
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: bdiv_results[('whole-body', 'weighted_unifrac')].to_excel('tables/table3f.xlsx', na_rep='NA', float_format="%1.3f")
bdiv_results[('whole-body', 'weighted_unifrac')]
# Out:
#                     uc      ucr     ucrC    ucrss  ucrss_wfilter  uc_fast  \
# uc                 NaN  0.94742  0.89564  0.93433        0.94257  0.95997
# ucr                NaN      NaN  0.89958  0.92423        0.94983  0.95082
# ucrC               NaN      NaN      NaN  0.88576        0.92416  0.90725
# ucrss              NaN      NaN      NaN      NaN        0.94404  0.92023
# ucrss_wfilter      NaN      NaN      NaN      NaN            NaN  0.93333
# uc_fast            NaN      NaN      NaN      NaN            NaN      NaN
# ucr_fast           NaN      NaN      NaN      NaN            NaN      NaN
# ucrC_fast          NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast         NaN      NaN      NaN      NaN            NaN      NaN
# ucrss_fast_wfilter NaN      NaN      NaN      NaN            NaN      NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                   0.93908    0.89794     0.90381             0.93587
# ucr                  0.92024    0.90377     0.87088             0.94386
# ucrC                 0.91116    0.99398     0.83136             0.93889
# ucrss                0.91664    0.88246     0.91841             0.91070
# ucrss_wfilter        0.91832    0.92575     0.89680             0.93162
# uc_fast              0.95490    0.90857     0.88950             0.96583
# ucr_fast                 NaN    0.91048     0.93554             0.95136
# ucrC_fast                NaN        NaN     0.82984             0.94028
# ucrss_fast               NaN        NaN         NaN             0.86558
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %% [markdown]
# ## Table 4: Taxa summary correlation by method

# %%
taxa_corr_results = {}
for data_set_id in data_set_ids:
    taxa_corr_results[data_set_id] = {}
    for level in range(2,8):
        df = pd.DataFrame.from_csv("%s-otus/taxa_correlations/level_%d.csv" % (data_set_id, level))
        taxa_corr_results[data_set_id][level] = df.copy()

# %%
if write_xls_files: taxa_corr_results['88-soils'][2].to_excel('tables/table4a.xlsx', na_rep='NA', float_format="%1.3f")
taxa_corr_results['88-soils'][2]
# Out:
#                     uc       ucr      ucrC     ucrss  ucrss_wfilter   uc_fast  \
# uc                 NaN  0.999998  0.983181  0.999997       0.999998  0.999996
# ucr                NaN       NaN  0.983160  0.999999       0.999999  0.999996
# ucrC               NaN       NaN       NaN  0.983147       0.983165  0.983156
# ucrss              NaN       NaN       NaN       NaN       0.999998  0.999995
# ucrss_wfilter      NaN       NaN       NaN       NaN            NaN  0.999995
# uc_fast            NaN       NaN       NaN       NaN            NaN       NaN
# ucr_fast           NaN       NaN       NaN       NaN            NaN       NaN
# ucrC_fast          NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast         NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast_wfilter NaN       NaN       NaN       NaN            NaN       NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                  0.999996   0.981320    0.999996            0.999995
# ucr                 0.999997   0.981302    0.999997            0.999996
# ucrC                0.983157   0.999455    0.983152            0.983168
# ucrss               0.999996   0.981290    0.999996            0.999995
# ucrss_wfilter       0.999996   0.981309    0.999996            0.999995
# uc_fast             0.999998   0.981299    0.999999            0.999998
# ucr_fast                 NaN   0.981299    1.000000            1.000000
# ucrC_fast                NaN        NaN    0.981294            0.981310
# ucrss_fast               NaN        NaN         NaN            0.999999
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: taxa_corr_results['88-soils'][7].to_excel('tables/table4b.xlsx', na_rep='NA', float_format="%1.3f")
taxa_corr_results['88-soils'][7]
# Out:
#                     uc       ucr      ucrC     ucrss  ucrss_wfilter   uc_fast  \
# uc                 NaN  0.939448  0.849721  0.939429       0.939433  0.999694
# ucr                NaN       NaN  0.820697  0.999992       0.999990  0.939538
# ucrC               NaN       NaN       NaN  0.820677       0.820729  0.849934
# ucrss              NaN       NaN       NaN       NaN       0.999982  0.939520
# ucrss_wfilter      NaN       NaN       NaN       NaN            NaN  0.939526
# uc_fast            NaN       NaN       NaN       NaN            NaN       NaN
# ucr_fast           NaN       NaN       NaN       NaN            NaN       NaN
# ucrC_fast          NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast         NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast_wfilter NaN       NaN       NaN       NaN            NaN       NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                  0.939752   0.839735    0.939631            0.939830
# ucr                 0.998175   0.923148    0.998058            0.998126
# ucrC                0.819635   0.818193    0.819658            0.820185
# ucrss               0.998170   0.923148    0.998053            0.998120
# ucrss_wfilter       0.998167   0.923154    0.998050            0.998120
# uc_fast             0.939894   0.840394    0.939776            0.939982
# ucr_fast                 NaN   0.920705    0.999882            0.999942
# ucrC_fast                NaN        NaN    0.920747            0.920906
# ucrss_fast               NaN        NaN         NaN            0.999826
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: taxa_corr_results['moving-pictures'][2].to_excel('tables/table4c.xlsx', na_rep='NA', float_format="%1.3f")
taxa_corr_results['moving-pictures'][2]
# Out:
#                     uc       ucr      ucrC     ucrss  ucrss_wfilter   uc_fast  \
# uc                 NaN  0.999997  0.997003  0.999992       0.999659  0.999997
# ucr                NaN       NaN  0.997004  0.999998       0.999665  1.000000
# ucrC               NaN       NaN       NaN  0.997000       0.997387  0.996999
# ucrss              NaN       NaN       NaN       NaN       0.999665  0.999998
# ucrss_wfilter      NaN       NaN       NaN       NaN            NaN  0.999664
# uc_fast            NaN       NaN       NaN       NaN            NaN       NaN
# ucr_fast           NaN       NaN       NaN       NaN            NaN       NaN
# ucrC_fast          NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast         NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast_wfilter NaN       NaN       NaN       NaN            NaN       NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                  0.999996   0.996827    0.999987            0.998449
# ucr                 1.000000   0.996831    0.999993            0.998460
# ucrC                0.997000   0.999844    0.997001            0.997601
# ucrss               0.999999   0.996828    0.999995            0.998460
# ucrss_wfilter       0.999665   0.997216    0.999660            0.999489
# uc_fast             1.000000   0.996824    0.999993            0.998460
# ucr_fast                 NaN   0.996826    0.999994            0.998461
# ucrC_fast                NaN        NaN    0.996830            0.997426
# ucrss_fast               NaN        NaN         NaN            0.998457
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: taxa_corr_results['moving-pictures'][7].to_excel('tables/table4d.xlsx', na_rep='NA', float_format="%1.3f")
taxa_corr_results['moving-pictures'][7]
# Out:
#                     uc      ucr      ucrC     ucrss  ucrss_wfilter   uc_fast  \
# uc                 NaN  0.96386  0.928748  0.963730       0.963212  0.999477
# ucr                NaN      NaN  0.963125  0.999977       0.999305  0.966905
# ucrC               NaN      NaN       NaN  0.963242       0.963341  0.933715
# ucrss              NaN      NaN       NaN       NaN       0.999292  0.966773
# ucrss_wfilter      NaN      NaN       NaN       NaN            NaN  0.966236
# uc_fast            NaN      NaN       NaN       NaN            NaN       NaN
# ucr_fast           NaN      NaN       NaN       NaN            NaN       NaN
# ucrC_fast          NaN      NaN       NaN       NaN            NaN       NaN
# ucrss_fast         NaN      NaN       NaN       NaN            NaN       NaN
# ucrss_fast_wfilter NaN      NaN       NaN       NaN            NaN       NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                  0.923112   0.881559    0.923047            0.919501
# ucr                 0.954344   0.922883    0.954292            0.950571
# ucrC                0.925086   0.916942    0.925425            0.925011
# ucrss               0.954287   0.923035    0.954257            0.950519
# ucrss_wfilter       0.953421   0.923123    0.953378            0.952243
# uc_fast             0.927224   0.886843    0.927174            0.923658
# ucr_fast                 NaN   0.884533    0.999968            0.996988
# ucrC_fast                NaN        NaN    0.884863            0.884356
# ucrss_fast               NaN        NaN         NaN            0.996978
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: taxa_corr_results['whole-body'][2].to_excel('tables/table4e.xlsx', na_rep='NA', float_format="%1.3f")
taxa_corr_results['whole-body'][2]
# Out:
#                     uc       ucr      ucrC     ucrss  ucrss_wfilter   uc_fast  \
# uc                 NaN  0.999992  0.998880  0.999992       0.999990  0.999989
# ucr                NaN       NaN  0.998881  0.999999       0.999999  0.999991
# ucrC               NaN       NaN       NaN  0.998878       0.998882  0.998895
# ucrss              NaN       NaN       NaN       NaN       0.999998  0.999991
# ucrss_wfilter      NaN       NaN       NaN       NaN            NaN  0.999991
# uc_fast            NaN       NaN       NaN       NaN            NaN       NaN
# ucr_fast           NaN       NaN       NaN       NaN            NaN       NaN
# ucrC_fast          NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast         NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast_wfilter NaN       NaN       NaN       NaN            NaN       NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                  0.999989   0.997646    0.999964            0.999987
# ucr                 0.999995   0.997640    0.999969            0.999994
# ucrC                0.998887   0.999008    0.998880            0.998878
# ucrss               0.999995   0.997638    0.999970            0.999993
# ucrss_wfilter       0.999995   0.997641    0.999967            0.999995
# uc_fast             0.999997   0.997654    0.999972            0.999993
# ucr_fast                 NaN   0.997648    0.999976            0.999996
# ucrC_fast                NaN        NaN    0.997641            0.997641
# ucrss_fast               NaN        NaN         NaN            0.999968
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %%
if write_xls_files: taxa_corr_results['whole-body'][7].to_excel('tables/table4f.xlsx', na_rep='NA', float_format="%1.3f")
taxa_corr_results['whole-body'][7]
# Out:
#                     uc       ucr      ucrC     ucrss  ucrss_wfilter   uc_fast  \
# uc                 NaN  0.958787  0.899610  0.958781       0.958771  0.999723
# ucr                NaN       NaN  0.917773  0.999997       0.999996  0.956702
# ucrC               NaN       NaN       NaN  0.917759       0.917776  0.896388
# ucrss              NaN       NaN       NaN       NaN       0.999993  0.956695
# ucrss_wfilter      NaN       NaN       NaN       NaN            NaN  0.956685
# uc_fast            NaN       NaN       NaN       NaN            NaN       NaN
# ucr_fast           NaN       NaN       NaN       NaN            NaN       NaN
# ucrC_fast          NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast         NaN       NaN       NaN       NaN            NaN       NaN
# ucrss_fast_wfilter NaN       NaN       NaN       NaN            NaN       NaN
#
#                     ucr_fast  ucrC_fast  ucrss_fast  ucrss_fast_wfilter
# uc                  0.912856   0.878695    0.913000            0.912872
# ucr                 0.966950   0.871130    0.966822            0.966951
# ucrC                0.892513   0.934549    0.892270            0.892576
# ucrss               0.966942   0.871108    0.966815            0.966944
# ucrss_wfilter       0.966952   0.871175    0.966821            0.966957
# uc_fast             0.911841   0.875543    0.911992            0.911853
# ucr_fast                 NaN   0.854585    0.999900            0.999989
# ucrC_fast                NaN        NaN    0.854332            0.854682
# ucrss_fast               NaN        NaN         NaN            0.999887
# ucrss_fast_wfilter       NaN        NaN         NaN                 NaN
#
# [10 rows x 10 columns]

# %% [markdown]
# ## Table 5: Run time by method

# %%
from datetime import datetime
from calendar import month_abbr

month_lookup = {v: k for k,v in enumerate(month_abbr)}

# %%
log_fps = glob('*/*/log*txt')

results = []
for log_fp in log_fps:
    fp_fields = log_fp.split('/')
    data_set_id = fp_fields[0].strip('-otus')
    run_id = fp_fields[1]
    d = !grep "^Logging" $log_fp
    start_fields = d[0].split()
    start_hour, start_minute, start_second = map(int, start_fields[3].split(':'))
    start_day, start_month, start_year = map(int, [start_fields[5], month_lookup[start_fields[6]], start_fields[7]])
    end_fields = d[1].split()
    end_hour, end_minute, end_second = map(int, end_fields[3].split(':'))
    end_day, end_month, end_year = map(int, [end_fields[5], month_lookup[end_fields[6]], end_fields[7]])
    start_datetime = datetime(start_year, start_month, start_day, start_hour, start_minute, start_second)
    end_datetime = datetime(end_year, end_month, end_day, end_hour, end_minute, end_second)
    runtime = (end_datetime - start_datetime).seconds
    results.append((run_id, data_set_id, runtime))

df = pd.DataFrame.from_records(results, columns=['abbreviation','data set id', 'runtime (s)'])
df = df.merge(method_descriptions, left_on="abbreviation", right_index=True)
df = df[df['processors'] <= 10]
df = df.pivot('abbreviation', 'data set id', 'runtime (s)')
df = df.reindex_axis(order, axis=0)

# %%
if write_xls_files: df.to_excel('tables/table5.xlsx', na_rep='NA', float_format="%1.3f")
df
# Out:
# data set id         88-soil  moving-picture  whole-body
# uc                     1220           27748        1095
# ucr                    1358           46576        1082
# ucrC                    226           28572         388
# ucrss                  1493           47207        1212
# ucrss_wfilter          1885           76061        2088
# uc_fast                 914           23510         489
# ucr_fast               1052           19371         621
# ucrC_fast                44            2428          68
# ucrss_fast             1021           23710         707
# ucrss_fast_wfilter     1525           52811        1661
#
# [10 rows x 3 columns]

# %% [markdown]
# ## Table 6: Subsampled OTU parameter variations

# %%
df = pd.DataFrame.from_records(results, columns=['abbreviation','data set id', 'runtime (s)'])
df = df.merge(method_descriptions, left_on="abbreviation", right_index=True)
df = df[df['processors'] == 29]
df = df.pivot('abbreviation', 'data set id', 'runtime (s)')

# %%
if write_xls_files: df.to_excel('tables/table6.xlsx', na_rep='NA', float_format="%1.3f")
df
# Out:
# data set id         moving-picture
# abbreviation
# ucr_fast_O29_r82             21737
# ucr_fast_O29_r97             16241
# ucrss_fast_O29_r82           17812
# ucrss_fast_O29_r97           16169
# ucrss_fast_O29_s1            14911
#
# [5 rows x 1 columns]

# %%
df['moving-picture']['ucr_fast_O29_r82'] - df['moving-picture']['ucrss_fast_O29_r82']
# Out:
# 3925

# %%
df['moving-picture']['ucr_fast_O29_r97'] - df['moving-picture']['ucrss_fast_O29_r97']
# Out:
# 72

# %% [markdown]
# ## Table 7: Novel OTUs by biome

# %%
novel_by_biome = pd.io.parsers.read_csv('raw-tables/fraction-novel-by-env-biome.tsv', sep='\t', index_col=0)
if write_xls_files: novel_by_biome.to_excel('tables/table7.xlsx', na_rep='NA', float_format="%1.3f")
novel_by_biome
# Out:
#                                                        Average de novo OTUs (10K sequences per sample)  \
# EnvironmentalBiome
# mangrove biome                                                                                    2169
# tropical humid forests                                                                            2398
# tundra biome                                                                                      1771
# deserts and xeric shrubland biome                                                                 3917
# taiga                                                                                             2598
# marine biome                                                                                      2040
# aquatic biome                                                                                      714
# freshwater biome                                                                                   768
# warm deserts and semideserts                                                                      2386
# tropical and subtropical moist broadleaf forest biome                                             3072
# temperate needle-leaf forests or woodlands                                                        2836
# polar biome                                                                                       1721
# tropical and subtropical coniferous forest biome                                                  1993
# mixed island systems                                                                              1552
# marginal sea                                                                                      1795
# temperate coniferous forest biome                                                                 2504
# mediterranean forests, woodlands, and shrub biome                                                  695
# large river biome                                                                                 1844
# terrestrial biome                                                                                 2714
# nest of bird                                                                                       821
# Temperate broadleaf and mixed forest biome                                                        1910
# temperate grasslands                                                                              2745
# animal-associated habitat                                                                          758
# mammalia-associated habitat                                                                        973
# Cold-winter (continental) deserts and semideserts                                                  847
# Temperate grasslands, savannas, and shrubland biome                                               1688
# human-associated habitat                                                                           292
#
#                                                        SD de novo OTUs (10K sequences per sample)  \
# EnvironmentalBiome
# mangrove biome                                                                               1159
# tropical humid forests                                                                        260
# tundra biome                                                                                  403
# deserts and xeric shrubland biome                                                             127
# taiga                                                                                         102
# marine biome                                                                                 1048
# aquatic biome                                                                                 299
# freshwater biome                                                                              541
# warm deserts and semideserts                                                                  473
# tropical and subtropical moist broadleaf forest biome                                         125
# temperate needle-leaf forests or woodlands                                                    159
# polar biome                                                                                   886
# tropical and subtropical coniferous forest biome                                              256
# mixed island systems                                                                          618
# marginal sea                                                                                  325
# temperate coniferous forest biome                                                            1206
# mediterranean forests, woodlands, and shrub biome                                             361
# large river biome                                                                             629
# terrestrial biome                                                                             222
# nest of bird                                                                                  276
# Temperate broadleaf and mixed forest biome                                                    491
# temperate grasslands                                                                          290
# animal-associated habitat                                                                     329
# mammalia-associated habitat                                                                   357
# Cold-winter (continental) deserts and semideserts                                             210
# Temperate grasslands, savannas, and shrubland biome                                           272
# human-associated habitat                                                                      242
#
#                                                        Average Reference OTUs (10k sequences per sample)  \
# EnvironmentalBiome
# mangrove biome                                                                                       354
# tropical humid forests                                                                               397
# tundra biome                                                                                         312
# deserts and xeric shrubland biome                                                                    707
# taiga                                                                                                505
# marine biome                                                                                         484
# aquatic biome                                                                                        177
# freshwater biome                                                                                     194
# warm deserts and semideserts                                                                         607
# tropical and subtropical moist broadleaf forest biome                                                846
# temperate needle-leaf forests or woodlands                                                           785
# polar biome                                                                                          483
# tropical and subtropical coniferous forest biome                                                     579
# mixed island systems                                                                                 511
# marginal sea                                                                                         611
# temperate coniferous forest biome                                                                    885
# mediterranean forests, woodlands, and shrub biome                                                    275
# large river biome                                                                                    743
# terrestrial biome                                                                                   1138
# nest of bird                                                                                         355
# Temperate broadleaf and mixed forest biome                                                           879
# temperate grasslands                                                                                1315
# animal-associated habitat                                                                            376
# mammalia-associated habitat                                                                          583
# Cold-winter (continental) deserts and semideserts                                                    551
# Temperate grasslands, savannas, and shrubland biome                                                 1497
# human-associated habitat                                                                             590
#
#                                                        SD Reference OTUs (10k sequences per sample)  \
# EnvironmentalBiome
# mangrove biome                                                                                   73
# tropical humid forests                                                                           35
# tundra biome                                                                                    117
# deserts and xeric shrubland biome                                                                15
# taiga                                                                                            35
# marine biome                                                                                    410
# aquatic biome                                                                                   199
# freshwater biome                                                                                120
# warm deserts and semideserts                                                                    147
# tropical and subtropical moist broadleaf forest biome                                            18
# temperate needle-leaf forests or woodlands                                                      132
# polar biome                                                                                     218
# tropical and subtropical coniferous forest biome                                                 94
# mixed island systems                                                                            203
# marginal sea                                                                                    225
# temperate coniferous forest biome                                                               201
# mediterranean forests, woodlands, and shrub biome                                               195
# large river biome                                                                               369
# terrestrial biome                                                                               163
# nest of bird                                                                                    138
# Temperate broadleaf and mixed forest biome                                                      235
# temperate grasslands                                                                            164
# animal-associated habitat                                                                       240
# mammalia-associated habitat                                                                     222
# Cold-winter (continental) deserts and semideserts                                               215
# Temperate grasslands, savannas, and shrubland biome                                             275
# human-associated habitat                                                                        366
#
#                                                        % novel diversity (10k seqs per sample)  \
# EnvironmentalBiome
# mangrove biome                                                                           0.860
# tropical humid forests                                                                   0.858
# tundra biome                                                                             0.850
# deserts and xeric shrubland biome                                                        0.847
# taiga                                                                                    0.837
# marine biome                                                                             0.808
# aquatic biome                                                                            0.801
# freshwater biome                                                                         0.798
# warm deserts and semideserts                                                             0.797
# tropical and subtropical moist broadleaf forest biome                                    0.784
# temperate needle-leaf forests or woodlands                                               0.783
# polar biome                                                                              0.781
# tropical and subtropical coniferous forest biome                                         0.775
# mixed island systems                                                                     0.752
# marginal sea                                                                             0.746
# temperate coniferous forest biome                                                        0.739
# mediterranean forests, woodlands, and shrub biome                                        0.717
# large river biome                                                                        0.713
# terrestrial biome                                                                        0.705
# nest of bird                                                                             0.698
# Temperate broadleaf and mixed forest biome                                               0.685
# temperate grasslands                                                                     0.676
# animal-associated habitat                                                                0.668
# mammalia-associated habitat                                                              0.625
# Cold-winter (continental) deserts and semideserts                                        0.606
# Temperate grasslands, savannas, and shrubland biome                                      0.530
# human-associated habitat                                                                 0.331
#
#                                                        % error novel diversity (10K seqs per sample)  \
# EnvironmentalBiome
# mangrove biome                                                                                 0.460
# tropical humid forests                                                                         0.094
# tundra biome                                                                                   0.201
# deserts and xeric shrubland biome                                                              0.028
# taiga                                                                                          0.035
# marine biome                                                                                   0.446
# aquatic biome                                                                                  0.403
# freshwater biome                                                                               0.576
# warm deserts and semideserts                                                                   0.166
# tropical and subtropical moist broadleaf forest biome                                          0.032
# temperate needle-leaf forests or woodlands                                                     0.057
# polar biome                                                                                    0.414
# tropical and subtropical coniferous forest biome                                               0.106
# mixed island systems                                                                           0.315
# marginal sea                                                                                   0.164
# temperate coniferous forest biome                                                              0.361
# mediterranean forests, woodlands, and shrub biome                                              0.424
# large river biome                                                                              0.282
# terrestrial biome                                                                              0.072
# nest of bird                                                                                   0.262
# Temperate broadleaf and mixed forest biome                                                     0.195
# temperate grasslands                                                                           0.082
# animal-associated habitat                                                                      0.359
# mammalia-associated habitat                                                                    0.270
# Cold-winter (continental) deserts and semideserts                                              0.215
# Temperate grasslands, savannas, and shrubland biome                                            0.121
# human-associated habitat                                                                       0.498
#
#                                                        number of samples
# EnvironmentalBiome
# mangrove biome                                                         7
# tropical humid forests                                                26
# tundra biome                                                         110
# deserts and xeric shrubland biome                                      7
# taiga                                                                  4
# marine biome                                                         890
# aquatic biome                                                        762
# freshwater biome                                                     375
# warm deserts and semideserts                                          97
# tropical and subtropical moist broadleaf forest biome                  2
# temperate needle-leaf forests or woodlands                            21
# polar biome                                                          277
# tropical and subtropical coniferous forest biome                       3
# mixed island systems                                                 124
# marginal sea                                                           7
# temperate coniferous forest biome                                     19
# mediterranean forests, woodlands, and shrub biome                    371
# large river biome                                                      5
# terrestrial biome                                                    627
# nest of bird                                                         313
# Temperate broadleaf and mixed forest biome                            14
# temperate grasslands                                                 696
# animal-associated habitat                                           1036
# mammalia-associated habitat                                         1918
# Cold-winter (continental) deserts and semideserts                    102
# Temperate grasslands, savannas, and shrubland biome                   85
# human-associated habitat                                            1597
#
# [27 rows x 7 columns]

# %% [markdown]
# ## Table 8: Differential OTU representation

# %%
gs_fp_sets = [glob('%s-otus/*/group_significance*txt' % id_) for id_ in data_set_ids]
gs_results = {}
n = 25

for data_set_id, gs_fp_set in zip(data_set_ids, gs_fp_sets):
    df = None
    for fp in gs_fp_set:
        run_id = fp.split('/')[1]
        id_ = (data_set_id, run_id)
        new_df = pd.DataFrame.from_csv(fp, sep='\t')
        gs_results[id_] = new_df[['taxonomy', 'Test-Statistic']][:n]

# %%
if write_xls_files: gs_results[('88-soils', 'ucrss')][:10].to_excel('tables/table8a.xlsx', na_rep='NA', float_format="%1.3f")
gs_results[('88-soils', 'ucrss')][:10]
# Out:
#                                                              taxonomy  \
# OTU
# 113212              k__Bacteria;p__Acidobacteria;c__DA052;o__Ellin...
# 1123837             k__Bacteria;p__Actinobacteria;c__Rubrobacteria...
# New.ReferenceOTU22  k__Bacteria;p__Actinobacteria;c__Actinobacteri...
# 252012              k__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 843189              k__Bacteria;p__Acidobacteria;c__Solibacteres;o...
# 1127423             k__Bacteria;p__Acidobacteria;c__Acidobacteriia...
# 1129210             k__Bacteria;p__Acidobacteria;c__Acidobacteriia...
# 831520              k__Bacteria;p__Actinobacteria;c__Rubrobacteria...
# 1139779             k__Bacteria;p__Proteobacteria;c__Alphaproteoba...
# 804187              k__Bacteria;p__Acidobacteria;c__[Chloracidobac...
#
#                     Test-Statistic
# OTU
# 113212                   55.858724
# 1123837                  50.432793
# New.ReferenceOTU22       49.171544
# 252012                   48.649686
# 843189                   47.005758
# 1127423                  43.869989
# 1129210                  43.804418
# 831520                   43.624935
# 1139779                  41.862548
# 804187                   41.151350
#
# [10 rows x 2 columns]

# %%
gs_results[('88-soils', 'ucrss')]['taxonomy']['New.ReferenceOTU22']
# Out:
# 'k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Actinomycetales;f__;g__;s__'

# %%
if write_xls_files: gs_results[('moving-pictures', 'ucrss')][:10].to_excel('tables/table8b.xlsx', na_rep='NA', float_format="%1.3f")
gs_results[('moving-pictures', 'ucrss')][:10]
# Out:
#                                                   taxonomy  Test-Statistic
# OTU
# 368134   k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacill...     1599.696001
# 3154070  k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...     1625.703076
# 1000986  k__Bacteria;p__Actinobacteria;c__Actinobacteri...     1630.009468
# 1992     k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...     1728.164420
# 4304475  k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...     1545.444829
# 191238   k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...     1546.435699
# 187665   k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...     1474.529300
# 4396297  k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...     1585.014965
# 3903651  k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...     1670.188332
# 3472078  k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...     1783.487973
#
# [10 rows x 2 columns]

# %%
if write_xls_files: gs_results[('whole-body', 'ucrss')][:10].to_excel('tables/table8c.xlsx', na_rep='NA', float_format="%1.3f")
gs_results[('whole-body', 'ucrss')][:10]
# Out:
#                                                                         taxonomy  \
# OTU
# 4326219                        k__Bacteria;p__Proteobacteria;c__Epsilonproteo...
# New.CleanUp.ReferenceOTU222    k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...
# 4325533                        k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...
# New.CleanUp.ReferenceOTU17550  k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...
# 316732                         k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...
# 4346374                        k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o_...
# 4458959                        k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...
# 3866487                        k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...
# 4391641                        k__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 175751                         k__Bacteria;p__Firmicutes;c__Clostridia;o__Clo...
#
#                                Test-Statistic
# OTU
# 4326219                            363.881085
# New.CleanUp.ReferenceOTU222        358.019614
# 4325533                            349.852497
# New.CleanUp.ReferenceOTU17550      337.655669
# 316732                             337.309334
# 4346374                            331.432928
# 4458959                            329.771577
# 3866487                            323.487958
# 4391641                            311.999639
# 175751                             305.530588
#
# [10 rows x 2 columns]

# %%
gs_results[('whole-body', 'ucrss')]['taxonomy']['New.CleanUp.ReferenceOTU222']
# Out:
# 'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Prevotella;s__melaninogenica'

# %%
gs_results[('whole-body', 'ucrss')]['taxonomy']['New.CleanUp.ReferenceOTU17550']
# Out:
# 'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Veillonellaceae;g__Veillonella;s__parvula'

# %% [markdown]
# ## Miscellaneous notes

# %% [markdown]
# Confirming that the closed-reference step of ``ucr`` and ``ucrss`` have equal numbers of sequences failing to hit the reference.
#
# ```bash
# $ wc -l *-otus/ucrss/step1_otus/*_failures.txt *-otus/ucr/uclust_ref_picked_otus/*_failures.txt
#     79662 88-soils-otus/ucrss/step1_otus/study_103_split_library_seqs_failures.txt
#     79662 88-soils-otus/ucr/uclust_ref_picked_otus/study_103_split_library_seqs_failures.txt
#   2805981 moving-pictures-otus/ucrss/step1_otus/study_550_split_library_seqs_failures.txt
#   2805981 moving-pictures-otus/ucr/uclust_ref_picked_otus/study_550_split_library_seqs_failures.txt
#     58736 whole-body-otus/ucrss/step1_otus/study_449_split_library_seqs_failures.txt
#     58736 whole-body-otus/ucr/uclust_ref_picked_otus/study_449_split_library_seqs_failures.txt
#
# $ wc -l *-otus/ucrss_fast/step1_otus/*_failures.txt *-otus/ucr_fast/uclust_ref_picked_otus/*_failures.txt
#     84565 88-soils-otus/ucrss_fast/step1_otus/study_103_split_library_seqs_failures.txt
#     84565 88-soils-otus/ucr_fast/uclust_ref_picked_otus/study_103_split_library_seqs_failures.txt
#   3432893 moving-pictures-otus/ucrss_fast/step1_otus/study_550_split_library_seqs_failures.txt
#   3432893 moving-pictures-otus/ucr_fast/uclust_ref_picked_otus/study_550_split_library_seqs_failures.txt
#     73254 whole-body-otus/ucrss_fast/step1_otus/study_449_split_library_seqs_failures.txt
#     73254 whole-body-otus/ucr_fast/uclust_ref_picked_otus/study_449_split_library_seqs_failures.txt
# ```

# %% [markdown]
# Computing the number of sequences being clusstered in each data set.
#
# ```bash
# count_seqs.py -i $MOVING_PICTURES_SEQS,$SOILS_SEQS,$WHOLE_BODY_SEQS
#
# 151387  : /home/caporaso/analysis/88-soils/study_103_split_library_seqs.fna (Sequence lengths (mean +/- std): 230.7818 +/- 11.4761)
# 792831  : /home/caporaso/analysis/whole-body/study_449_split_library_seqs.fna (Sequence lengths (mean +/- std): 228.5124 +/- 16.0318)
# 68666081  : /home/caporaso/analysis/moving-pictures/study_550_split_library_seqs.fna (Sequence lengths (mean +/- std): 123.2359 +/- 17.4283)
# ```
